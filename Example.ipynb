# %%
from heuristic_methods import alternating_strategy
from summary import solve
from test_matrices import A
from numpy import kron

# %% [markdown]
# Lower bounds are found in: https://arxiv.org/pdf/1407.4308
#
# Example of a lower bound without diagonal scaling:
#
# ![image.png](attachment:image.png)
#
# Same lower bound but with diagonal scaling:
#
# ![image-2.png](attachment:image-2.png)

# %%
solve(A)
# Out:
# Lower Bounds:
# B1: 2.000
# B3_gradient: 1.665
# B3D_gradient: 2.285
# B3_newton: 1.475
# B4: 2.000
# B4D: 2.633
# B5: 2.863
# B5D: 2.553
# Upper Bounds:
# mindim_upper_bound: 3.000
# hadamard_sqrt_upper_bound: 3.000
# PSD-rank is 3 for matrix :
# [1, 0, 0]
# [0.5, 0.5, 0]
# [0.5, 0, 0.5]
# [3]

# %%
solve(kron(A,A))

# %%
alternating_strategy(A,4)
# Out:
# PSD-rank is 3 for matrix :
# [1.0, 0.0, 0.0]
# [0.5, 0.5, 0.0]
# [0.5, 0.0, 0.5]
# A eigenvalues and matrices
# [[ 0.0684+0.j     -0.0114-0.0014j -0.1704+0.0035j]
#  [-0.0114+0.0014j  0.0019+0.j      0.0283-0.0041j]
#  [-0.1704-0.0035j  0.0283+0.0041j  0.4246+0.j    ]]
# [7.92876378e-07 2.84486462e-06 4.94923925e-01]
#
#
# [[ 0.1414+0.j     -0.053 +0.0004j -0.0009-0.0004j]
#  [-0.053 -0.0004j  0.021 +0.j     -0.0125-0.001j ]
#  [-0.0009+0.0004j -0.0125+0.001j   0.1529+0.j    ]]
# [4.82812826e-06 1.52421604e-01 1.62853343e-01]
#
#
# [[ 0.0031+0.j     -0.0033+0.0001j -0.0074+0.0001j]
#  [-0.0033-0.0001j  0.2284+0.j     -0.0151+0.002j ]
#  [-0.0074-0.0001j -0.0151-0.002j   0.0202+0.j    ]]
# [4.05970773e-06 2.21215562e-02 2.29522343e-01]
#
#
#
#  B eigenvalues and matrices
# [[ 1.3648+0.j      0.2273-0.0042j -0.2782+0.0078j]
#  [ 0.2273+0.0042j  2.0035+0.j      0.0924-0.0003j]
#  [-0.2782-0.0078j  0.0924+0.0003j  1.9026+0.j    ]]
# [1.17415521 2.02050028 2.07634605]
#
#
# ...

# %%
alternating_strategy(A)
# Out:
# PSD-rank is 3 for matrix :
# [1.0, 0.0, 0.0]
# [0.5, 0.5, 0.0]
# [0.5, 0.0, 0.5]
# A eigenvalues and matrices
# [[ 1.6920441 +0.j         -0.28704675+0.02114835j -1.89462685-0.0343683j ]
#  [-0.28704675-0.02114835j  0.04898105+0.j          0.32095967+0.02951069j]
#  [-1.89462685+0.0343683j   0.32095967-0.02951069j  2.12220315+0.j        ]]
# [2.58285820e-06 4.03887348e-05 3.86318533e+00]
#
#
# [[ 0.27572212+0.j         -0.31724898-0.00266135j -0.00777298+0.00380339j]
#  [-0.31724898+0.00266135j  0.67312768+0.j         -0.33393843-0.00742016j]
#  [-0.00777298-0.00380339j -0.33393843+0.00742016j  0.38186231+0.j        ]]
# [4.55011287e-06 3.38131602e-01 9.92575957e-01]
#
#
# [[ 0.65476973+0.j         -0.13648324+0.00621218j -0.52575045-0.00895471j]
#  [-0.13648324-0.00621218j  0.0340321 +0.j          0.0647162 +0.00938757j]
#  [-0.52575045+0.00895471j  0.0647162 -0.00938757j  0.78744843+0.j        ]]
# [1.17353532e-05 2.09352244e-01 1.26688628e+00]
#
#
#
#  B eigenvalues and matrices
# ...
